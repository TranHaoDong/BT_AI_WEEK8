# %% [markdown]
# <a href="https://colab.research.google.com/github/TranHaoDong/BT_AI_WEEK9-15/blob/main/Week10/Boston_housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import boston_housing
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sas
(x_train,y_train),(x_test,y_test)= boston_housing.load_data()
data = pd.DataFrame(x_train,y_train )
sas.pairplot(data)
plt.show()

# %%
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (404, 13)
# (102, 13)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train1 = sc.fit_transform(x_train)
x_test1 = sc.fit_transform(x_test)

# %%
from keras.utils import to_categorical 
y_train1 = to_categorical(y_train, 100) #chuyển sang 100 kênh
y_test1 = to_categorical(y_test, 100)

# %%
from keras.models import  Sequential
from keras.layers import Dense

# %%
from keras.models import Sequential
from keras.layers import Dense

model= Sequential()
model.add(Dense(1024, input_shape = (13,), activation = 'relu'))
model.add(Dense(512,activation= 'relu'))
model.add(Dense(1,activation= 'sigmoid'))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 1024)              14336
#
#  dense_13 (Dense)            (None, 512)               524800
#
#  dense_14 (Dense)            (None, 1)                 513
#
# ...
# Total params: 539,649
# Trainable params: 539,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer= 'Adam', loss= 'mean_absolute_error', metrics= ['accuracy'])
model.fit(x_train1, y_train1, epochs= 3, batch_size= 128)
test_loss, test_acc = model.evaluate(x_test1, y_test1)
print('Test_accuracy: ',test_acc)
print('Test_loss: ', test_loss)
# Out:
# Epoch 1/3
# 4/4 [==============================] - 1s 23ms/step - loss: 0.3025 - accuracy: 0.8978
# Epoch 2/3
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0357 - accuracy: 0.9900
# Epoch 3/3
# ...
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9900
# Test_accuracy:  0.9900000095367432
# Test_loss:  0.010381695814430714
